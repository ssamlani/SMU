# %%
import pandas as pd
import os

# %%
baseFile = "201801-citibike-tripdata"

# %%
os.getcwd()
# Out:
# '/Users/ssamlani/Desktop/BikeData'

# %%
allFilePaths = []

for i in range(1, 13):
    #get month in format used in file name
    month = i
    if (i < 10):
        #months less than 10 need a leading 0
        month = "0" + str(i)
    #print(month)
    
    #create filename dynamically
    subFolder = "AllFiles/"
    fileName = f"JC-2018{month}-citibike-tripdata.csv"
    allFilePaths.append(fileName)
    
#Print all file paths
allFilePaths
# Out:
# ['JC-201801-citibike-tripdata.csv',
#  'JC-201802-citibike-tripdata.csv',
#  'JC-201803-citibike-tripdata.csv',
#  'JC-201804-citibike-tripdata.csv',
#  'JC-201805-citibike-tripdata.csv',
#  'JC-201806-citibike-tripdata.csv',
#  'JC-201807-citibike-tripdata.csv',
#  'JC-201808-citibike-tripdata.csv',
#  'JC-201809-citibike-tripdata.csv',
#  'JC-201810-citibike-tripdata.csv',
#  'JC-201811-citibike-tripdata.csv',
#  'JC-201812-citibike-tripdata.csv']

# %%
df = pd.DataFrame()

for path in allFilePaths:
    df = df.append(pd.read_csv(path))
    
# df.info()

# %%
len(df)
# Out:
# 353892

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
df.starttime = pd.to_datetime(df.starttime)
df.stoptime = pd.to_datetime(df.stoptime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353892 entries, 0 to 20204
# Data columns (total 15 columns):
# tripduration               353892 non-null int64
# starttime                  353892 non-null datetime64[ns]
# stoptime                   353892 non-null datetime64[ns]
# start station id           353892 non-null int64
# start station name         353892 non-null object
# start station latitude     353892 non-null float64
# start station longitude    353892 non-null float64
# end station id             353892 non-null int64
# end station name           353892 non-null object
# end station latitude       353892 non-null float64
# end station longitude      353892 non-null float64
# bikeid                     353892 non-null int64
# usertype                   353892 non-null object
# birth year                 353892 non-null int64
# gender                     353892 non-null int64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(3)
# memory usage: 43.2+ MB

# %%
df["Month"] = [x.month for x in df.starttime]
df["Day"] = [x.day for x in df.starttime]

# %%
df.tail()
# Out:
#        tripduration               starttime                stoptime  \
# 20200          1081 2018-12-22 11:51:46.060 2018-12-22 12:09:47.473
# 20201           344 2018-12-25 21:40:09.866 2018-12-25 21:45:54.267
# 20202          1233 2018-12-29 12:55:45.969 2018-12-29 13:16:19.596
# 20203          1057 2018-12-30 15:32:09.332 2018-12-30 15:49:46.351
# 20204           301 2018-12-31 16:34:11.934 2018-12-31 16:39:13.834
#
#        start station id start station name  start station latitude  \
# 20200              3694     Jackson Square                40.71113
# 20201              3694     Jackson Square                40.71113
# 20202              3694     Jackson Square                40.71113
# 20203              3694     Jackson Square                40.71113
# 20204              3694     Jackson Square                40.71113
#
#        start station longitude  end station id         end station name  \
# 20200                 -74.0789            3269          Brunswick & 6th
# ...

# %%
dfSub = df.sample(frac=0.02, random_state=45)

dfSub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7078 entries, 21575 to 182
# Data columns (total 17 columns):
# tripduration               7078 non-null int64
# starttime                  7078 non-null datetime64[ns]
# stoptime                   7078 non-null datetime64[ns]
# start station id           7078 non-null int64
# start station name         7078 non-null object
# start station latitude     7078 non-null float64
# start station longitude    7078 non-null float64
# end station id             7078 non-null int64
# end station name           7078 non-null object
# end station latitude       7078 non-null float64
# end station longitude      7078 non-null float64
# bikeid                     7078 non-null int64
# usertype                   7078 non-null object
# birth year                 7078 non-null int64
# gender                     7078 non-null int64
# Month                      7078 non-null int64
# Day                        7078 non-null int64
# ...

# %%
dfSub.groupby(["Month"]).Month.count() / len(dfSub)
# Out:
# Month
# 1     0.036734
# 2     0.042809
# 3     0.049308
# 4     0.069652
# 5     0.102147
# 6     0.111048
# 7     0.107799
# 8     0.132241
# 9     0.106245
# 10    0.112037
# 11    0.070359
# 12    0.059621
# Name: Month, dtype: float64

# %%
df.groupby(["Month"]).Month.count() / len(df)
# Out:
# Month
# 1     0.035822
# 2     0.042680
# 3     0.048345
# 4     0.066783
# 5     0.097363
# 6     0.115677
# 7     0.119438
# 8     0.125552
# 9     0.110265
# 10    0.110593
# 11    0.070389
# 12    0.057094
# Name: Month, dtype: float64

# %%
dfSub.to_csv("randomSample.csv", index=False)

# %%
pd.read_csv("randomSample.csv")
# Out:
#       tripduration                starttime                 stoptime  \
# 0              121  2018-10-02 21:25:51.501  2018-10-02 21:27:52.783
# 1              288  2018-10-02 08:03:12.636  2018-10-02 08:08:01.088
# 2              725  2018-09-07 16:20:20.515  2018-09-07 16:32:25.864
# 3              266  2018-06-27 08:31:20.011  2018-06-27 08:35:46.102
# 4              254  2018-03-03 09:33:54.675  2018-03-03 09:38:08.948
# ...            ...                      ...                      ...
# 7073           374  2018-08-03 17:41:56.295  2018-08-03 17:48:11.180
# 7074           427  2018-11-04 10:17:30.489  2018-11-04 10:24:38.011
# 7075           283  2018-08-09 10:03:41.038  2018-08-09 10:08:24.749
# 7076           549  2018-05-09 17:48:54.030  2018-05-09 17:58:03.308
# 7077           329  2018-08-02 21:10:58.956  2018-08-02 21:16:28.501
#
#       start station id start station name  start station latitude  \
# 0                 3211         Newark Ave               40.721525
# ...
